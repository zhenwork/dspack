# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import time
import h5py
import os,sys
import numpy as np
import matplotlib.pyplot as plt

# %%
DSPACK_HOME=os.environ.get("DSPACK_HOME")
if DSPACK_HOME not in sys.path:
    sys.path.append(DSPACK_HOME)

# %%
import scripts.fsystem

# %%
workdir = "/reg/data/ana03/scratch/zhensu/Experiment/ICH/20201225/"
dnames = ["WT-1", "WT-2", "WT-3", "G150A-1", "G150A-2", "G150A-3", "G150T-1", "G150T-2", "G150T-3"]

# %% [markdown]
# ## Raw Image

# %%
fname = "%s/data/PIPELINE/datadir/image_file_2021_01_23_00_38_40_475047_00000_image_raw.h5"%workdir
image = scripts.fsystem.H5manager.reader(fname,"image")

# %%
data = image[985:1478,1481:1682].copy()

plt.figure(figsize=(9,3))
plt.imshow(data[:,::-1].T,clim=(0+1e-3,60-1e-3),cmap="Greys")
plt.axis("off")
plt.xticks([],[])
plt.yticks([],[])
cbar = plt.colorbar(fraction=0.018, pad=0.02)
cbar.ax.tick_params(labelsize=20)

plt.subplots_adjust(top=1, bottom=0)
plt.tight_layout(pad=-1,h_pad=-10,w_pad=-10)
plt.savefig("./600dpi/Fig_02_Image_Raw.jpg",dpi=600,bbox_inches='tight',pad_inches=0,transparent=True)
plt.show()

# %% [markdown]
# ## Raw Backg

# %%
fname = "%s/data/PIPELINE/datadir/image_file_2021_01_23_00_38_40_475047_00000_backg_raw.h5"%workdir
image = scripts.fsystem.H5manager.reader(fname,"image")

# %%
data = image[985:1478,1481:1682].copy()

plt.figure(figsize=(9,3))
plt.imshow(data[:,::-1].T,clim=(0+1e-3,60-1e-3),cmap="Greys")
plt.axis("off")
plt.xticks([],[])
plt.yticks([],[])
cbar = plt.colorbar(fraction=0.018, pad=0.02)
cbar.ax.tick_params(labelsize=20)

plt.subplots_adjust(top=1, bottom=0)
plt.tight_layout(pad=-1,h_pad=-10,w_pad=-10)
plt.savefig("./600dpi/Fig_02_Backg_Raw.jpg",dpi=600,bbox_inches='tight',pad_inches=0,transparent=True)
plt.show()

# %% [markdown]
# ## Image Background Subtraction

# %%
fname = "%s/data/PIPELINE/datadir/image_file_2021_01_23_00_38_40_475047_00000_image_mask_deep_backgsub.h5"%workdir
image = scripts.fsystem.H5manager.reader(fname,"image")
mask = scripts.fsystem.H5manager.reader(fname,"mask")
image *= mask

# %%
data = image[985:1478,1481:1682].copy()

plt.figure(figsize=(9,3))
plt.imshow(data[:,::-1].T,clim=(0+1e-3,60-1e-3),cmap="Greys")
plt.axis("off")
plt.xticks([],[])
plt.yticks([],[])
cbar = plt.colorbar(fraction=0.018, pad=0.02)
cbar.ax.tick_params(labelsize=20)

plt.subplots_adjust(top=1, bottom=0)
plt.tight_layout(pad=-1,h_pad=-10,w_pad=-10)
plt.savefig("./600dpi/Fig_02_Image_Mask_Deep_BackgSub.jpg",dpi=600,bbox_inches='tight',pad_inches=0,transparent=True)
plt.show()

# %% [markdown]
# ## Image Background Subtraction + Pixel Correction

# %%
fname = "%s/data/PIPELINE/datadir/image_file_2021_01_23_00_38_40_475047_00000_image_mask_deep_backgsub_intposcorr.h5"%workdir
image = scripts.fsystem.H5manager.reader(fname,"image")
mask = scripts.fsystem.H5manager.reader(fname,"mask")
image *= mask

# %%
data = image[985:1478,1481:1682].copy()

plt.figure(figsize=(9,3))
plt.imshow(data[:,::-1].T,clim=(0+1e-3,60-1e-3),cmap="Greys")
plt.axis("off")
plt.xticks([],[])
plt.yticks([],[])
cbar = plt.colorbar(fraction=0.018, pad=0.02)
cbar.ax.tick_params(labelsize=20)

plt.subplots_adjust(top=1, bottom=0)
plt.tight_layout(pad=-1,h_pad=-10,w_pad=-10)
plt.savefig("./600dpi/Fig_02_Image_Mask_Deep_BackgSub_IPCorr.jpg",dpi=600,bbox_inches='tight',pad_inches=0,transparent=True)
plt.show()

# %% [markdown]
# ## Image Background Subtraction + Pixel Correction + Bragg Peak Cleaning

# %%
fname = "%s/data/PIPELINE/datadir/image_file_2021_01_23_00_38_40_475047_00000_image_mask_deep_backgsub_intposcorr_braggclean.h5"%workdir
image = scripts.fsystem.H5manager.reader(fname,"image")
mask = scripts.fsystem.H5manager.reader(fname,"mask")
image *= mask

# %%
data = image[985:1478,1481:1682].copy()

plt.figure(figsize=(9,3))
plt.imshow(data[:,::-1].T,clim=(0+1e-3,60-1e-3),cmap="Greys")
plt.axis("off")
plt.xticks([],[])
plt.yticks([],[])
cbar = plt.colorbar(fraction=0.018, pad=0.02)
cbar.ax.tick_params(labelsize=20)

plt.subplots_adjust(top=1, bottom=0)
plt.tight_layout(pad=-1,h_pad=-10,w_pad=-10)
plt.savefig("./600dpi/Fig_02_Image_Mask_Deep_BackgSub_IPCorr_Bragg.jpg",dpi=600,bbox_inches='tight',pad_inches=0,transparent=True)
plt.show()

# %% [markdown]
# ## Image Background Subtraction + Pixel Correction + Bragg Peak Cleaning + Scale&PCA

# %%
fname = "%s/data/WT-1/standard_clean_data_scale_profile_with_pca.dsdata"%workdir
image_file = scripts.fsystem.H5manager.reader(fname,"image_file")[0]
scale_factor = np.load(scripts.fsystem.H5manager.reader(fname,"scale_factor"))[0]
image = scripts.fsystem.H5manager.reader(image_file,"image") * scale_factor
mask = scripts.fsystem.H5manager.reader(image_file,"mask")
image *= mask
print scale_factor, scale_factor==1.0
# Out:
# 1.0 True

# %%
data = image[985:1478,1481:1682].copy()

plt.figure(figsize=(9,3))
plt.imshow(data[:,::-1].T,clim=(0+1e-3,60-1e-3),cmap="Greys")
plt.axis("off")
plt.xticks([],[])
plt.yticks([],[])
cbar = plt.colorbar(fraction=0.018, pad=0.02)
cbar.ax.tick_params(labelsize=20)

plt.subplots_adjust(top=1, bottom=0)
plt.tight_layout(pad=-1,h_pad=-10,w_pad=-10)
plt.savefig("./600dpi/Fig_02_Image_Mask_Deep_BackgSub_IPCorr_Bragg_ScalePCA.jpg",dpi=600,bbox_inches='tight',pad_inches=0,transparent=True)
plt.show()

# %%
import scripts.image 
import scripts.fsystem
import scripts.statistics

# %%
zfilter = scripts.image.FilterTools()
mean_filter = zfilter.mean_filter

# %%
def cut_slice(data, mask, center, idx, half_depth=2):
    v = data * mask
    if idx == 0:
        image = np.sum(v[(center-half_depth):(center+half_depth+1),:,:],axis=0)
        masks = np.sum(mask[(center-half_depth):(center+half_depth+1),:,:],axis=0)
        index = np.where(masks>0)
        image[index] /= masks[index]
        image[masks<=0] = -1024
        return image
    if idx == 1:
        image = np.sum(v[:,(center-half_depth):(center+half_depth+1),:],axis=1)
        masks = np.sum(mask[:,(center-half_depth):(center+half_depth+1),:],axis=1)
        index = np.where(masks>0)
        image[index] /= masks[index]
        image[masks<=0] = -1024
        return image
    if idx == 2:
        image = np.sum(v[:,:,(center-half_depth):(center+half_depth+1)],axis=2)
        masks = np.sum(mask[:,:,(center-half_depth):(center+half_depth+1)],axis=2)
        index = np.where(masks>0)
        image[index] /= masks[index]
        image[masks<=0] = -1024
        return image

# %%
Vmin = {'G150A-1': [-1.5837136892290515, -3.3653499153339697, -2.4988260438265],
 'G150A-2': [-1.3085976556424059, -1.9441395690353866, -1.413119694407835],
 'G150A-3': [-1.3213963913834506, -3.3774080422108375, -2.5288549652067731],
 'G150T-1': [-1.252499273728664, -2.0422783730322829, -1.275232579196333],
 'G150T-2': [-2.0082480303734629, -3.3005483093697183, -2.1954999398702348],
 'G150T-3': [-2.8020105628911578, -4.0617032001808386, -2.9940249951647515],
 'WT-1': [-3.3971781954256599, -5.5333633083606006, -4.2284963359614265],
 'WT-2': [-1.2603902051742468, -2.7291167307734496, -2.3694521045805081],
 'WT-3': [-3.5749026932743067, -5.0271376013239939, -4.0240326066706436]}
Vmax = {'G150A-1': [1.8634379881319059, 2.5481483092320936, 1.5314349072800775],
 'G150A-2': [1.2179239573423215, 2.0655173792984849, 1.3002491767011688],
 'G150A-3': [1.7506255138303741, 2.5099189858109723, 1.7651150848639274],
 'G150T-1': [1.0765227737565475, 1.8526097852763597, 1.236134576643247],
 'G150T-2': [1.8965472490714963, 3.2021016547664227, 2.262069063046916],
 'G150T-3': [2.4454652729471102, 4.1958699252009302, 2.4847784751535631],
 'WT-1': [3.9014425533447992, 4.9940212421931136, 2.923434477008902],
 'WT-2': [1.4750139655477206, 2.2302708278543948, 1.4199920711013192],
 'WT-3': [3.1354703168739455, 4.8600660417996302, 3.2603364677379565]}

# %%
half_depth = 4 # box length 2*depth+1
dname = "WT-1"

# %% [markdown]
# ## Merged Diffraction Volume

# %%
fname = "%s/data/%s/standard_clean_data_scale_profile_with_pca_map1.dsdata_map3.dsdata"%(workdir,dname)
path_volume = scripts.fsystem.H5manager.reader(fname,"merge_volume")
with h5py.File(path_volume, "r") as f:
    oversample = f["oversample"][()]
    exp_xyz = f["volume_xyz"][()]
    voxel_length_invA = np.linalg.norm(f["Bmat_invA"][:,1]) * 1.0 / oversample
    max_voxel_radius = 1./1.4/voxel_length_invA

# %%
import matplotlib.cm

plt.figure(figsize=(9,4))

cut_idx = 0
x = np.arange(361)-180
x,y = np.meshgrid(x,x,indexing="ij")
r = np.sqrt(x**2+y**2)
exp_slice = cut_slice(exp_xyz, (exp_xyz>0).astype(int), 180, cut_idx, half_depth=half_depth)
exp_slice[r>max_voxel_radius] = -1024

pattern = exp_slice.copy()
mask = (pattern>0).astype(int)
pattern = zfilter.mean_filter(image=pattern,mask=mask,window=(3,3))
pattern[mask==0]=-1024 

masked_array = np.ma.masked_where(pattern == -1024, pattern)
cmap = matplotlib.cm.nipy_spectral
cmap.set_bad(color='white')

plt.imshow(masked_array.T, clim=(10+1e-2, 53),cmap=cmap)
plt.axis("off")
plt.xticks([],[])
plt.yticks([],[])

dx = 82
dy = 42
plt.xlim(180-int(dx),180+int(dx))
plt.ylim(172-int(dy)*2,172)
cbar = plt.colorbar(fraction=0.046, pad=0.02)
cbar.ax.tick_params(labelsize=20)

plt.subplots_adjust(top=1, bottom=0)
plt.tight_layout(pad=-1,h_pad=-10,w_pad=-10)
plt.savefig("./600dpi/Fig_02_Volume_Nosym_Nosub.jpg",dpi=600,bbox_inches='tight',pad_inches=0,transparent=True)
plt.show()

# %% [markdown]
# ## Laue Symmetrization

# %%
fname = "%s/data/%s/standard_clean_data_scale_profile_with_pca_map1.dsdata_map3.dsdata"%(workdir,dname)
path_volume = scripts.fsystem.H5manager.reader(fname,"merge_volume")
with h5py.File(path_volume, "r") as f:
    oversample = f["oversample"][()]
    exp_sym_xyz = f["volume_laue_sym_xyz"][()]
    voxel_length_invA = np.linalg.norm(f["Bmat_invA"][:,1]) * 1.0 / oversample
    max_voxel_radius = 1./1.4/voxel_length_invA

# %%
import matplotlib.cm

plt.figure(figsize=(9,4))

cut_idx = 0
x = np.arange(361)-180
x,y = np.meshgrid(x,x,indexing="ij")
r = np.sqrt(x**2+y**2)
exp_slice = cut_slice(exp_sym_xyz, (exp_sym_xyz>0).astype(int), 180, cut_idx, half_depth=half_depth)
exp_slice[r>max_voxel_radius] = -1024

pattern = exp_slice.copy()
mask = (pattern>0).astype(int)
pattern = zfilter.mean_filter(image=pattern,mask=mask,window=(3,3))
pattern[mask==0]=-1024 

masked_array = np.ma.masked_where(pattern == -1024, pattern)
cmap = matplotlib.cm.nipy_spectral
cmap.set_bad(color='white')
    
plt.imshow(masked_array.T, clim=(10+1e-2, 53),cmap=cmap)
plt.axis("off")
plt.xticks([],[])
plt.yticks([],[])

dx = 82
dy = 42
plt.xlim(180-int(dx),180+int(dx))
plt.ylim(172-int(dy)*2,172)
cbar = plt.colorbar(fraction=0.046, pad=0.02)
cbar.ax.tick_params(labelsize=20)

plt.subplots_adjust(top=1, bottom=0)
plt.tight_layout(pad=-1,h_pad=-10,w_pad=-10)
plt.savefig("./600dpi/Fig_02_Volume_Sym_Nosub.jpg",dpi=600,bbox_inches='tight',pad_inches=0,transparent=True)
plt.show()

# %% [markdown]
# ## Isotropic Component Subtraction

# %%
fname = "%s/data/%s/standard_clean_data_scale_profile_with_pca_map1.dsdata_map3.dsdata"%(workdir,dname)
path_volume = scripts.fsystem.H5manager.reader(fname,"merge_volume")
with h5py.File(path_volume, "r") as f:
    oversample = f["oversample"][()]
    exp_sym_sub_xyz = f["volume_laue_sym_backg_sub_xyz"][()]
    voxel_length_invA = np.linalg.norm(f["Bmat_invA"][:,1]) * 1.0 / oversample
    max_voxel_radius = 1./1.4/voxel_length_invA

# %%
import matplotlib.cm

plt.figure(figsize=(9,4))

cut_idx = 0
x = np.arange(361)-180
x,y = np.meshgrid(x,x,indexing="ij")
r = np.sqrt(x**2+y**2)
exp_slice = cut_slice(exp_sym_sub_xyz, (exp_sym_sub_xyz>-100).astype(int), 180, cut_idx, half_depth=half_depth)
exp_slice[r>max_voxel_radius] = -1024

pattern = exp_slice.copy()
mask = (pattern>-100).astype(int)
pattern = zfilter.mean_filter(image=pattern,mask=mask,window=(3,3))
pattern[mask==0]=-1024 

masked_array = np.ma.masked_where(pattern == -1024, pattern)
cmap = matplotlib.cm.nipy_spectral
cmap.set_bad(color='white')

vmin = Vmin[dname][cut_idx]
vmax = Vmax[dname][cut_idx]

plt.imshow(masked_array.T, clim=(vmin, vmax),cmap=cmap)
plt.axis("off")
plt.xticks([],[])
plt.yticks([],[])

dx = 82
dy = 42
plt.xlim(180-int(dx),180+int(dx))
plt.ylim(172-int(dy)*2,172)
cbar = plt.colorbar(fraction=0.046, pad=0.02)
cbar.ax.tick_params(labelsize=20)

plt.subplots_adjust(top=1, bottom=0)
plt.tight_layout(pad=-1,h_pad=-10,w_pad=-10)
plt.savefig("./600dpi/Fig_02_Volume_Sym_Aniso.jpg",dpi=600,bbox_inches='tight',pad_inches=0,transparent=True)
plt.show()

# %%
## Compare difference
fname = "%s/data/PIPELINE/datadir/image_file_2021_01_23_00_38_40_475047_00000_image_mask_deep_backgsub_intposcorr_braggclean.h5"%workdir
image = scripts.fsystem.H5manager.reader(fname,"image")
mask = scripts.fsystem.H5manager.reader(fname,"mask")

fname = "%s/data/WT-1/standard_clean_data.dsdata"%workdir
image_file = scripts.fsystem.H5manager.reader(fname,"image_file")[0]
image2 = scripts.fsystem.H5manager.reader(image_file,"image")
mask2 = scripts.fsystem.H5manager.reader(image_file,"mask")
print np.sum((image-image2)**2), np.sum((mask-mask2)**2)
# Out:
# 0.0 0
